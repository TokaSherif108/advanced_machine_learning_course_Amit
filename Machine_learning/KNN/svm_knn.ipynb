# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("C:/Users/toka_/Desktop/AMIT/advanced_machine_learning_course_Amit/Machine_learning/KNN/data.csv")

# %%
data.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data['diagnosis']=data["diagnosis"].map({'M':1,"B":0})

# %%
data.head(11)
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302          1        17.99         10.38          122.80     1001.0
# 1     842517          1        20.57         17.77          132.90     1326.0
# 2   84300903          1        19.69         21.25          130.00     1203.0
# 3   84348301          1        11.42         20.38           77.58      386.1
# 4   84358402          1        20.29         14.34          135.10     1297.0
# 5     843786          1        12.45         15.70           82.57      477.1
# 6     844359          1        18.25         19.98          119.60     1040.0
# 7   84458202          1        13.71         20.83           90.20      577.9
# 8     844981          1        13.00         21.82           87.50      519.8
# 9   84501001          1        12.46         24.04           83.97      475.9
# 10    845636          1        16.02         23.24          102.70      797.8
#
# ...

# %%
X=data.drop(["id","Unnamed: 32","diagnosis"],axis=1).values
X=X.reshape(-1,X.shape[1])
y=data["diagnosis"].values
y=y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### KNN Algorithm

# %%
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import StandardScaler 
model=KNeighborsClassifier(n_neighbors=5,metric="minkowski",p=2)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score 
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9385964912280702

# %% [markdown]
# Normalization

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
#classifier=KNeighborsClassifier
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9385964912280702

# %% [markdown]
# SVM

# %%
data=pd.read_csv("C:/Users/toka_/Desktop/AMIT/advanced_machine_learning_course_Amit/Machine_learning/KNN/customer_purchases.csv")
data.head(11)
# Out:
#     Age  Salary  Purchased
# 0    19   19000          0
# 1    35   20000          0
# 2    26   43000          0
# 3    27   57000          0
# 4    19   76000          0
# 5    27   58000          0
# 6    27   84000          0
# 7    32  150000          1
# 8    25   33000          0
# 9    35   65000          0
# 10   26   80000          0

# %%
x=data.iloc[:,[0,1]].values
y=data.iloc[:2].values
from
