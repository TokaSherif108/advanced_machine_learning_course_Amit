# %% [markdown]
# ### AMAZON SALES DATA ANALYSIS

# %% [markdown]
# ![image.png](attachment:a37f4257-6a34-467a-9997-958f3d9ecbca.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/kaggle/input/unlock-profits-with-e-commerce-sales-data/Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
df= df.drop(df.columns[-1],axis=1) 
df = df.drop('index', axis = 1)

# %%
df.head(3)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ... Qty currency  Amount    ship-city   ship-state ship-postal-code  \
# 0  ...   0      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1  ...   1      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2  ...   1      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#   ship-country                                      promotion-ids    B2B  \
# 0           IN                                                NaN  False
# 1           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2           IN       IN Core Free Shipping 2015/04/08 23-48-5-108   True
#
#   fulfilled-by
# 0    Easy Ship
# 1    Easy Ship
# 2          NaN
#
# [3 rows x 22 columns]

# %%
df.describe()
# Out:
#                  Qty         Amount  ship-postal-code
# count  128975.000000  121180.000000     128942.000000
# mean        0.904431     648.561465     463966.236509
# std         0.313354     281.211687     191476.764941
# min         0.000000       0.000000     110001.000000
# 25%         1.000000     449.000000     382421.000000
# 50%         1.000000     605.000000     500033.000000
# 75%         1.000000     788.000000     600024.000000
# max        15.000000    5584.000000     989898.000000

# %%
df[df.duplicated()]
# Out:
#                   Order ID      Date     Status Fulfilment Sales Channel   \
# 30661  406-0372545-6086735  04-12-22  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120  04-05-22  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958  05-07-22  Cancelled     Amazon      Amazon.in
# 85791  171-3249942-2207542  05-03-22    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736  05-03-22    Shipped     Amazon      Amazon.in
# 98955  407-4853873-4978725  06-22-22    Shipped     Amazon      Amazon.in
#
#       ship-service-level    Style              SKU Category Size  ... Qty  \
# 30661          Expedited   SET197   SET197-KR-NP-L      Set    L  ...   0
# 41292          Expedited  JNE3501     JNE3501-KR-M    kurta    M  ...   0
# 79845          Expedited    J0329       J0329-KR-L    kurta    L  ...   0
# 85791          Expedited   SET323  SET323-KR-NP-XL      Set   XL  ...   1
# 86419          Expedited  MEN5025  MEN5025-KR-XXXL    kurta  3XL  ...   1
# 98955          Expedited    J0230      J0230-SKD-M      Set    M  ...   1
#
#       currency  Amount  ship-city     ship-state ship-postal-code  \
# 30661      NaN     NaN   Siliguri    WEST BENGAL         734008.0
# 41292      NaN     NaN  BENGALURU      KARNATAKA         560072.0
# 79845      NaN     NaN  ERNAKULAM         KERALA         682017.0
# 85791      INR   939.0       PUNE    MAHARASHTRA         411057.0
# 86419      INR   533.0  GHAZIABAD  UTTAR PRADESH         201010.0
# 98955      INR  1163.0   Zirakpur         Punjab         140603.0
#
#       ship-country                                 promotion-ids    B2B  \
# 30661           IN                                           NaN  False
# 41292           IN                                           NaN  False
# 79845           IN                                           NaN  False
# 85791           IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 86419           IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 98955           IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#       fulfilled-by
# 30661          NaN
# 41292          NaN
# 79845          NaN
# 85791          NaN
# 86419          NaN
# 98955          NaN
#
# [6 rows x 22 columns]

# %%
df = (df.drop_duplicates(keep='first').reset_index(drop=True)) # removed

# %%
df.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7792
# Amount                 7792
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49150
# B2B                       0
# fulfilled-by          89692
# dtype: int64

# %%
have_null_coll = ['Courier Status', 'currency', 'ship-city', 'ship-state', 'ship-country','promotion-ids']
for i in have_null_coll:
    mode = df[i].mode()[0]
    df[i] = df[i].fillna(mode)
df['Amount'] = df['Amount'].fillna(df['Amount'].median())

# %%
df.isna().sum() # now 0 missing value
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency                  0
# Amount                    0
# ship-city                 0
# ship-state                0
# ship-postal-code         33
# ship-country              0
# promotion-ids             0
# B2B                       0
# fulfilled-by          89692
# dtype: int64

# %%
IQR = df['Amount'].quantile(0.75) - df['Amount'].quantile(0.25)
1.5*IQR
upper_bound = df['Amount'].quantile(0.75) + 1.5*IQR   
lower_bound = df['Amount'].quantile(0.25) - 1.5*IQR 
Median = df['Amount'].median()
df['Amount'] = df['Amount'].apply(lambda x: Median if x > upper_bound  or x < lower_bound else x)

# %%
df['Amount'] = df['Amount'].apply(lambda x: Median if x == 0 else x)

# %%
fig, my_ax = plt.subplots(figsize=(8,5))

sns.histplot(data = df['Amount'], ax=my_ax, binwidth=100, kde=True)
plt.grid(linestyle='--',color='#000000')
plt.title("Distribution of Sales Amount across Count of Orders")
plt.tight_layout()

# %% [markdown]
# #####  Here we can see that most of the sells between 400-600 ₹

# %%
Top5_Trending_product=df.groupby('Category')['Amount'].sum().to_frame().sort_values(by=['Amount'],ascending=False).head(5)

# %%
Top5_Trending_product
# Out:
#                     Amount
# Category
# Set            38581957.01
# kurta          23692693.22
# Western Dress  11724761.12
# Top             5721433.30
# Ethnic Dress     832975.66

# %%
Top5_Trending_product.plot(kind='bar',color='#f0bda7')
plt.title('Total Amount by Category', fontsize=18, weight='bold')
plt.ylabel('Total Amount (in millions)', fontsize=14)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Here the top 5 most selling product in Amazon

# %%
Top5_cities_orderfrom_Amazon=df.groupby('ship-city')['Amount'].sum().to_frame().sort_values(by=['Amount'],ascending=False).head(5)

# %%
Top5_cities_orderfrom_Amazon
# Out:
#                Amount
# ship-city
# BENGALURU  7058584.03
# HYDERABAD  5094404.89
# MUMBAI     3802823.69
# NEW DELHI  3752356.03
# CHENNAI    3233757.37

# %%
Top5_cities_orderfrom_Amazon.plot(kind='bar',color='#a3fafb')
plt.title('Top 5 cities order from Amazon', fontsize=18, weight='bold')
plt.ylabel('Total Amount (in millions)', fontsize=14)
plt.grid(True, axis='y', linestyle='--',color='#000000', alpha=0.7)
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Here are the top 5 cities order from Amazon

# %%
Total_Qty_ordered = df['Qty'].sum()

# %%
Total_Sales = df['Amount'].sum()

# %%
Sales_Order_wise = df.groupby('Order ID').agg({'Qty': 'count', 'Amount': 'sum', 'Status': 'sum', 'Fulfilment': 'sum', 'ship-service-level': 'sum', 'ship-service-level': 'sum', 'Style': 'sum', 'SKU': 'sum', 'Category': 'sum', 'ship-city': 'sum', 'ship-state': 'sum', 'B2B': 'sum', 'promotion-ids': 'sum'})

# %%
Sales_Order_wise
# Out:
#                      Qty  Amount     Status Fulfilment ship-service-level  \
# Order ID
# 171-0000547-8192359    1   301.0    Shipped     Amazon          Expedited
# 171-0000902-4490745    1   544.0  Cancelled     Amazon          Expedited
# 171-0001409-6228339    1   422.0    Shipped     Amazon          Expedited
# 171-0003082-5110755    1   563.0    Shipped     Amazon          Expedited
# 171-0003738-2052324    1   379.0    Shipped     Amazon          Expedited
# ...                  ...     ...        ...        ...                ...
# S02-9578181-3610412    1   605.0    Shipped     Amazon           Standard
# S02-9599483-2736812    1   605.0   Shipping     Amazon           Standard
# S02-9649067-3246849    1   605.0    Shipped     Amazon           Standard
# S02-9736323-0094708    1   605.0    Shipped     Amazon           Standard
# S02-9878098-5959538    1   605.0    Shipped     Amazon           Standard
#
#                        Style                    SKU Category  \
# Order ID
# 171-0000547-8192359  JNE2032      JNE2032-KR-205-XL    kurta
# 171-0000902-4490745    J0097             J0097-KR-M    kurta
# 171-0001409-6228339  JNE3440        JNE3440-KR-N-XS    kurta
# 171-0003082-5110755   SET291         SET291-KR-PP-L      Set
# 171-0003738-2052324  JNE3440        JNE3440-KR-N-XS    kurta
# ...                      ...                    ...      ...
# S02-9578181-3610412   SET197         SET197-KR-NP-S      Set
# S02-9599483-2736812    J0012            J0012-SKD-L      Set
# S02-9649067-3246849  JNE3291           JNE3291-KR-L    kurta
# S02-9736323-0094708  JNE2153  JNE2153-KR-278-A-XXXL    kurta
# S02-9878098-5959538    J0012          J0012-SKD-XXL      Set
#
#                             ship-city     ship-state  B2B  \
# Order ID
# 171-0000547-8192359  PIMPRI CHINCHWAD    MAHARASHTRA    0
# 171-0000902-4490745            Howrah    WEST BENGAL    0
# 171-0001409-6228339             KODAD      TELANGANA    0
# 171-0003082-5110755     GREATER NOIDA  UTTAR PRADESH    0
# 171-0003738-2052324         FIROZABAD  UTTAR PRADESH    0
# ...                               ...            ...  ...
# S02-9578181-3610412             Surat        Gujarat    0
# S02-9599483-2736812             Surat        Gujarat    0
# S02-9649067-3246849             Surat        Gujarat    0
# S02-9736323-0094708             Surat        Gujarat    0
# S02-9878098-5959538             Surat        Gujarat    0
#
#                                                     promotion-ids
# Order ID
# 171-0000547-8192359  IN Core Free Shipping 2015/04/08 23-48-5-108
# 171-0000902-4490745  IN Core Free Shipping 2015/04/08 23-48-5-108
# 171-0001409-6228339  IN Core Free Shipping 2015/04/08 23-48-5-108
# 171-0003082-5110755  IN Core Free Shipping 2015/04/08 23-48-5-108
# 171-0003738-2052324  IN Core Free Shipping 2015/04/08 23-48-5-108
# ...                                                           ...
# S02-9578181-3610412  IN Core Free Shipping 2015/04/08 23-48-5-108
# S02-9599483-2736812  IN Core Free Shipping 2015/04/08 23-48-5-108
# S02-9649067-3246849  IN Core Free Shipping 2015/04/08 23-48-5-108
# S02-9736323-0094708  IN Core Free Shipping 2015/04/08 23-48-5-108
# S02-9878098-5959538  IN Core Free Shipping 2015/04/08 23-48-5-108
#
# [120378 rows x 12 columns]

# %%
Top5_seller_by_qt=Sales_Order_wise.sort_values(by='Qty', ascending = False).head(5)

# %%
Top5_seller_by_qt
# Out:
#                      Qty   Amount  \
# Order ID
# 403-4984515-8861958   12  5923.00
# 171-5057375-2831560   12  6227.62
# 404-9932919-6662730   11  5789.00
# 403-0173977-3041148   11  5976.00
# 408-3317403-1729937   10  5986.00
#
#                                                                 Status  \
# Order ID
# 403-4984515-8861958  ShippedShippedShippedShippedShippedShippedShip...
# 171-5057375-2831560  CancelledCancelledCancelledCancelledCancelledC...
# 404-9932919-6662730  Shipped - Delivered to BuyerShipped - Delivere...
# 403-0173977-3041148  Shipped - Delivered to BuyerShipped - Delivere...
# 408-3317403-1729937  Shipped - Delivered to BuyerShipped - Delivere...
#
#                                                             Fulfilment  \
# Order ID
# 403-4984515-8861958  AmazonAmazonAmazonAmazonAmazonAmazonAmazonAmaz...
# 171-5057375-2831560  MerchantMerchantMerchantMerchantMerchantMercha...
# 404-9932919-6662730  MerchantMerchantMerchantMerchantMerchantMercha...
# 403-0173977-3041148  MerchantMerchantMerchantMerchantMerchantMercha...
# 408-3317403-1729937  MerchantMerchantMerchantMerchantMerchantMercha...
#
#                                                     ship-service-level  \
# Order ID
# 403-4984515-8861958  ExpeditedExpeditedExpeditedExpeditedExpeditedE...
# 171-5057375-2831560  StandardStandardStandardStandardStandardStanda...
# 404-9932919-6662730  StandardStandardStandardStandardStandardStanda...
# 403-0173977-3041148  StandardStandardStandardStandardStandardStanda...
# 408-3317403-1729937  StandardStandardStandardStandardStandardStanda...
#
#                                                                  Style  \
# Order ID
# 403-4984515-8861958  JNE3792JNE3764JNE3503J0308JNE3702JNE3741JNE363...
# 171-5057375-2831560  J0210JNE3628JNE3476J0150JNE3786SET147SET288J01...
# 404-9932919-6662730  JNE3548JNE2100JNE3440JNE3630JNE3628SET184JNE36...
# 403-0173977-3041148  JNE3869JNE3720JNE3273JNE3738JNE3739JNE3861SET2...
# 408-3317403-1729937  JNE3437JNE3753JNE3787SET288JNE3726SET048SET220...
#
#                                                                    SKU  \
# Order ID
# 403-4984515-8861958  JNE3792-KR-XXXLJNE3764-KR-XXXLJNE3503-KR-XXXLJ...
# 171-5057375-2831560  J0210-DR-XXXLJNE3628-KR-XXXLJNE3476-KR-XXLJ015...
# 404-9932919-6662730  JNE3548-KR-XSJNE2100-KR-144-XSJNE3440-KR-N-XSJ...
# 403-0173977-3041148  JNE3869-DR-XXXLJNE3720-KR-XXXLJNE3273-KR-XXXLJ...
# 408-3317403-1729937  JNE3437-KR-XXXLJNE3753-KR-XXXLJNE3787-KR-XXXLS...
#
#                                                               Category  \
# Order ID
# 403-4984515-8861958  kurtakurtakurtaWestern DresskurtakurtakurtaSet...
# 171-5057375-2831560  Ethnic DresskurtakurtakurtakurtaSetSetTopkurta...
# 404-9932919-6662730    kurtakurtakurtakurtakurtaSetkurtaSetSetSetkurta
# 403-0173977-3041148  Western DresskurtakurtakurtakurtaWestern Dress...
# 408-3317403-1729937           kurtakurtakurtaSetkurtaSetSetSetSetkurta
#
#                                                              ship-city  \
# Order ID
# 403-4984515-8861958  SOLAPURSOLAPURSOLAPURSOLAPURSOLAPURSOLAPURSOLA...
# 171-5057375-2831560  CHENNAICHENNAICHENNAICHENNAICHENNAICHENNAICHEN...
# 404-9932919-6662730       PUNEPUNEPUNEPUNEPUNEPUNEPUNEPUNEPUNEPUNEPUNE
# 403-0173977-3041148  SOLAPURSOLAPURSOLAPURSOLAPURSOLAPURSOLAPURSOLA...
# 408-3317403-1729937  HYDERABADHYDERABADHYDERABADHYDERABADHYDERABADH...
#
#                                                             ship-state  B2B  \
# Order ID
# 403-4984515-8861958  MAHARASHTRAMAHARASHTRAMAHARASHTRAMAHARASHTRAMA...    0
# 171-5057375-2831560  TAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL ...    0
# 404-9932919-6662730  MAHARASHTRAMAHARASHTRAMAHARASHTRAMAHARASHTRAMA...    0
# 403-0173977-3041148  MAHARASHTRAMAHARASHTRAMAHARASHTRAMAHARASHTRAMA...    0
# 408-3317403-1729937  TELANGANATELANGANATELANGANATELANGANATELANGANAT...    0
#
#                                                          promotion-ids
# Order ID
# 403-4984515-8861958  IN Core Free Shipping 2015/04/08 23-48-5-108IN...
# 171-5057375-2831560  IN Core Free Shipping 2015/04/08 23-48-5-108IN...
# 404-9932919-6662730  Amazon PLCC Free-Financing Universal Merchant ...
# 403-0173977-3041148  Amazon PLCC Free-Financing Universal Merchant ...
# 408-3317403-1729937  Amazon PLCC Free-Financing Universal Merchant ...

# %%
_, my_ax = plt.subplots(figsize=(8, 5))
Top5_seller_by_qt.plot(kind='bar', ax=my_ax, width=0.4)
plt.xticks(rotation=1, fontsize=10)
plt.grid(linestyle='--',color='#000000')
plt.title("Top 5 Orders By Quantity", fontsize=14)
plt.ylabel("Amount")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
Top5_orderby_amount=Sales_Order_wise.sort_values(by='Amount', ascending = False).head(5)

# %%
Top5_orderby_amount
# Out:
#                      Qty   Amount  \
# Order ID
# 406-9002076-4152331    9  6509.00
# 171-0706521-2133101    9  6313.00
# 171-5057375-2831560   12  6227.62
# 404-3701762-8241125    9  6198.00
# 408-3317403-1729937   10  5986.00
#
#                                                                 Status  \
# Order ID
# 406-9002076-4152331  Shipped - Delivered to BuyerShipped - Delivere...
# 171-0706521-2133101  Shipped - Delivered to BuyerShipped - Delivere...
# 171-5057375-2831560  CancelledCancelledCancelledCancelledCancelledC...
# 404-3701762-8241125  ShippedShippedShippedShippedShippedShippedShip...
# 408-3317403-1729937  Shipped - Delivered to BuyerShipped - Delivere...
#
#                                                             Fulfilment  \
# Order ID
# 406-9002076-4152331  MerchantMerchantMerchantMerchantMerchantMercha...
# 171-0706521-2133101  MerchantMerchantMerchantMerchantMerchantMercha...
# 171-5057375-2831560  MerchantMerchantMerchantMerchantMerchantMercha...
# 404-3701762-8241125  AmazonAmazonAmazonAmazonAmazonAmazonAmazonAmaz...
# 408-3317403-1729937  MerchantMerchantMerchantMerchantMerchantMercha...
#
#                                                     ship-service-level  \
# Order ID
# 406-9002076-4152331  StandardStandardStandardStandardStandardStanda...
# 171-0706521-2133101  StandardStandardStandardStandardStandardStanda...
# 171-5057375-2831560  StandardStandardStandardStandardStandardStanda...
# 404-3701762-8241125  ExpeditedExpeditedExpeditedExpeditedExpeditedE...
# 408-3317403-1729937  StandardStandardStandardStandardStandardStanda...
#
#                                                                  Style  \
# Order ID
# 406-9002076-4152331  J0308J0302SET324J0338JNE3870SET267J0339J0295J0341
# 171-0706521-2133101  JNE3605SET058SET217JNE3440SET094SET233SET396JN...
# 171-5057375-2831560  J0210JNE3628JNE3476J0150JNE3786SET147SET288J01...
# 404-3701762-8241125  J0010JNE3607SET273JNE3634JNE3614SET279SET405SE...
# 408-3317403-1729937  JNE3437JNE3753JNE3787SET288JNE3726SET048SET220...
#
#                                                                    SKU  \
# Order ID
# 406-9002076-4152331  J0308-DR-XXXLJ0302-DR-XXLSET324-KR-NP-XXXLJ033...
# 171-0706521-2133101  JNE3605-KR-XXLSET058-KR-NP-XXLSET217-KR-PP-XXL...
# 171-5057375-2831560  J0210-DR-XXXLJNE3628-KR-XXXLJNE3476-KR-XXLJ015...
# 404-3701762-8241125  J0010-LCD-XSJNE3607-KR-XSSET273-KR-NP-XSJNE363...
# 408-3317403-1729937  JNE3437-KR-XXXLJNE3753-KR-XXXLJNE3787-KR-XXXLS...
#
#                                                               Category  \
# Order ID
# 406-9002076-4152331  Western DressWestern DressSetWestern DressWest...
# 171-0706521-2133101                  kurtaSetSetkurtaSetSetSetkurtaSet
# 171-5057375-2831560  Ethnic DresskurtakurtakurtakurtaSetSetTopkurta...
# 404-3701762-8241125                  SetkurtaSetkurtakurtaSetSetSetSet
# 408-3317403-1729937           kurtakurtakurtaSetkurtaSetSetSetSetkurta
#
#                                                              ship-city  \
# Order ID
# 406-9002076-4152331  HYDERABADHYDERABADHYDERABADHYDERABADHYDERABADH...
# 171-0706521-2133101  HYDERABADHYDERABADHYDERABADHYDERABADHYDERABADH...
# 171-5057375-2831560  CHENNAICHENNAICHENNAICHENNAICHENNAICHENNAICHEN...
# 404-3701762-8241125  PANCHKULAPANCHKULAPANCHKULAPANCHKULAPANCHKULAP...
# 408-3317403-1729937  HYDERABADHYDERABADHYDERABADHYDERABADHYDERABADH...
#
#                                                             ship-state  B2B  \
# Order ID
# 406-9002076-4152331  TELANGANATELANGANATELANGANATELANGANATELANGANAT...    0
# 171-0706521-2133101  TELANGANATELANGANATELANGANATELANGANATELANGANAT...    0
# 171-5057375-2831560  TAMIL NADUTAMIL NADUTAMIL NADUTAMIL NADUTAMIL ...    0
# 404-3701762-8241125  HARYANAHARYANAHARYANAHARYANAHARYANAHARYANAHARY...    0
# 408-3317403-1729937  TELANGANATELANGANATELANGANATELANGANATELANGANAT...    0
#
#                                                          promotion-ids
# Order ID
# 406-9002076-4152331  Amazon PLCC Free-Financing Universal Merchant ...
# 171-0706521-2133101  Amazon PLCC Free-Financing Universal Merchant ...
# 171-5057375-2831560  IN Core Free Shipping 2015/04/08 23-48-5-108IN...
# 404-3701762-8241125  IN Core Free Shipping 2015/04/08 23-48-5-108IN...
# 408-3317403-1729937  Amazon PLCC Free-Financing Universal Merchant ...

# %%
_, my_ax = plt.subplots(figsize=(8, 5))
Top5_orderby_amount.plot(kind='bar', ax=my_ax, width=0.4,color='#b6fb82')
plt.xticks(rotation=1, fontsize=10)
#plt.grid(color='#000000')
plt.title("Top 5 Orders By Amount", fontsize=14)
plt.ylabel("Amount")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
df['Month'] = pd.DatetimeIndex(df['Date']).month

# %%
df.head(3)
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#    ...  Amount    ship-city   ship-state ship-postal-code  ship-country  \
# 0  ...  647.62       MUMBAI  MAHARASHTRA         400081.0            IN
# 1  ...  406.00    BENGALURU    KARNATAKA         560085.0            IN
# 2  ...  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0       IN Core Free Shipping 2015/04/08 23-48-5-108  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
#
#    Year Month
# 0  2022     4
# 1  2022     4
# 2  2022     4
#
# [3 rows x 24 columns]

# %%
Orders_date_wise = df.groupby('Date').agg({'Qty': 'count', 'Amount': 'sum'}).sort_values(by='Amount', ascending = False).head(5)

# %%
Orders_date_wise
# Out:
#            Qty      Amount
# Date
# 05-03-22  2083  1256246.02
# 05-04-22  2015  1252189.24
# 05-02-22  2079  1242425.07
# 04-14-22  1883  1161562.27
# 04-23-22  1816  1135424.62

# %% [markdown]
# ##### Top 5 selling date

# %%
Orders_qt=df.groupby('Date').agg({'Qty': 'count', 'Amount': 'sum'}).sort_values(by='Qty', ascending = False).head(5)

# %%
Orders_qt
# Out:
#            Qty      Amount
# Date
# 05-03-22  2083  1256246.02
# 05-02-22  2079  1242425.07
# 05-04-22  2015  1252189.24
# 04-14-22  1883  1161562.27
# 04-15-22  1853  1107565.31

# %% [markdown]
# ##### Top 5 quantity ordered by user

# %%
order_status=df.groupby('Status').agg({'Qty': 'count', 'Amount': 'sum'}).sort_values(by='Qty', ascending = False)

# %%
order_status
# Out:
#                                  Qty       Amount
# Status
# Shipped                        77801  49183878.00
# Shipped - Delivered to Buyer   28769  18273278.00
# Cancelled                      18329  11251879.57
# Shipped - Returned to Seller    1953   1239811.00
# Shipped - Picked Up              973    648080.00
# Pending                          658    418395.00
# Pending - Waiting for Pick Up    281    191075.00
# Shipped - Returning to Seller    145    101676.00
# Shipped - Out for Delivery        35     23807.00
# Shipped - Rejected by Buyer       11      7295.00
# Shipping                           8      4840.00
# Shipped - Lost in Transit          5      3207.00
# Shipped - Damaged                  1      1136.00

# %%
_, my_ax = plt.subplots(figsize=(8, 5))
order_status.plot(kind='bar', ax=my_ax, width=0.4)
plt.xticks(rotation=1, fontsize=10)
#plt.grid()
plt.title("All Order Status", fontsize=14)
plt.ylabel("Amount")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# %%
Sales_month_wise = df.groupby('Month').agg({'Amount': 'sum', 'Qty': 'sum'})
Sales_month_wise
# Out:
#             Amount    Qty
# Month
# 3        104377.85    156
# 4      30213124.67  44206
# 5      26898800.65  38009
# 6      24132054.40  34275

# %%
Sales_month_wise.plot(kind='line',color='#f0bda7')
plt.title('Monthly sales', fontsize=18, weight='bold')
plt.ylabel('Total Amount (in millions)', fontsize=14)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.tight_layout()
plt.show()

# %%
Sales_percentage_by_fulfilment = (df.groupby('Fulfilment').agg({'Qty': 'count', 'Amount': 'sum'}).sort_values(by='Amount', ascending = False)['Amount']/81352807.57)*100
Sales_percentage_by_fulfilment
# Out:
# Fulfilment
# Amazon      69.500711
# Merchant    30.493819
# Name: Amount, dtype: float64

# %%
Sales_percentage_by_fulfilment.plot(kind='pie')
plt.tight_layout()
